# %%
# Read the simulated data
import pandas as pd
import math

def sigmoid(x):
    # sign = float(x)/abs(x) if x != 0 else 0 
    # return sign* math.log((abs(1000*x) + 1))
    return (1/(1+math.exp(-200*x)) - 0.5)

df = pd.read_csv("../data/MUT15-RS100index.csv")
# Note ts should already be in datetime
print "Dataset size: %s rows, %s columns" % df.shape
# set 'tick' as index
df.set_index("tick", inplace=True)
df["change_with_multiplier"] = df.change.apply(lambda x: x*100)
df["log_change"] = df.change.apply(sigmoid)
del df["change"] # for better logging
print df[15:20]
print df[48:54]
print df[50:80]
ts = df # Form a
pitch_var = "log_change" # "change_with_multiplier"
# Out:
# Dataset size: 120 rows, 4 columns
#       index_price  percent_change  change_with_multiplier  log_change
# tick
# 15        0.98592          0.0000                   0.000    0.000000
# 16        0.98768          0.0018                   0.176    0.087102
# 17        0.98768          0.0000                   0.000    0.000000
# 18        0.98768          0.0000                   0.000    0.000000
# 19        0.98768          0.0000                   0.000    0.000000
#       index_price  percent_change  change_with_multiplier  log_change
# tick
# 48        0.98945          0.0000                   0.000    0.000000
# 49        0.98945          0.0000                   0.000    0.000000
# 50        0.91742         -0.0785                  -7.203   -0.499999
# 51        0.91646         -0.0011                  -0.097   -0.048348
# 52        0.91624         -0.0002                  -0.022   -0.010998
# 53        0.91602         -0.0002                  -0.022   -0.010998
#       index_price  percent_change  change_with_multiplier  log_change
# tick
# 50        0.91742         -0.0785                  -7.203   -0.499999
# 51        0.91646         -0.0011                  -0.097   -0.048348
# 52        0.91624         -0.0002                  -0.022   -0.010998
# 53        0.91602         -0.0002                  -0.022   -0.010998
# 54        0.91524         -0.0009                  -0.078   -0.038921
# 55        0.91435         -0.0010                  -0.089   -0.044383
# 56        0.91346         -0.0010                  -0.088   -0.043887
# 57        0.91260         -0.0009                  -0.086   -0.042894
# 58        0.91175         -0.0009                  -0.086   -0.042894
# 59        0.91090         -0.0009                  -0.084   -0.041901
# 60        0.91007         -0.0009                  -0.083   -0.041405
# 61        0.90920         -0.0010                  -0.087   -0.043391
# 62        0.90832         -0.0010                  -0.088   -0.043887
# 63        0.90747         -0.0009                  -0.086   -0.042894
# 64        0.90658         -0.0010                  -0.089   -0.044383
# 65        0.90571         -0.0010                  -0.087   -0.043391
# 66        0.90485         -0.0010                  -0.086   -0.042894
# 67        0.90401         -0.0009                  -0.084   -0.041901
# 68        0.90318         -0.0009                  -0.083   -0.041405
# 69        0.90237         -0.0009                  -0.081   -0.040412
# 70        0.90157         -0.0009                  -0.080   -0.039915
# 71        0.90079         -0.0009                  -0.078   -0.038921
# 72        0.90001         -0.0009                  -0.078   -0.038921
# 73        0.89928         -0.0008                  -0.074   -0.036933
# 74        0.89852         -0.0008                  -0.075   -0.037430
# 75        0.89777         -0.0008                  -0.075   -0.037430
# 76        0.89698         -0.0009                  -0.080   -0.039915
# 77        0.89620         -0.0009                  -0.077   -0.038424
# 78        0.89538         -0.0009                  -0.083   -0.041405
# 79        0.89457         -0.0009                  -0.081   -0.040412

# %%
# plot time series and save the figure                                                                                                                                                        
# %matplotlib inline
import matplotlib
import seaborn as sns
fig = sns.plt.figure(figsize=(12, 8))

sns.plt.subplot(311)
sns.plt.plot(ts["log_change"], "-b")
sns.plt.ylabel("Logarithmic Change")
sns.plt.title("Istanbul Stock Exchange")

sns.plt.subplot(312)
sns.plt.plot(ts["percent_change"], "-g")
sns.plt.ylabel("Percentage Change")

sns.plt.subplot(313)
sns.plt.plot(ts["index_price"], "-r", lw=1)
sns.plt.xlabel("Ticks")
sns.plt.ylabel("Index Price")
sns.plt.show()
# Out:
# /home/ratish/wiseio/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from miditime.miditime import MIDITime
from datetime import timedelta, datetime

bpm = 120  # tempo in beats per minute (120bpm is the default)
out_file = '../data/simulated.mid'  # output file destination
secs_per_year = 73  # the number of seconds you want to represent a year in the final song (default is 5 sec/year)
base_octave = 5  # the base octave (C5 is middle C, so the default is 5, 
num_octaves = 3  # how many octaves you want your output to range over (default is 1)
# Instantiate the class
midi = MIDITime(bpm, out_file, secs_per_year, base_octave, num_octaves)

# Inded is just ticks, so, we need to convert it into dates. Let's just use a day for each tick
simulated_dates = map(lambda x: datetime(2016, 01, 01) + timedelta(x), ts.index)
ts["epoch"] = map(lambda x: midi.days_since_epoch(x), simulated_dates)
# Convert "days" since epoch" to number of beats since epoch. In the current config,
# we are using 5 seconds to define each year. TODO - explain
ts["beat"] = ts.epoch.apply(midi.beat)
start_time = ts.beat.iloc[0]
beats_per_second = bpm / 60.0
ts["song_time"] = ts["beat"].apply(lambda x: (x-start_time)/beats_per_second)
print ts.head()
# Out:
#       index_price  percent_change  change_with_multiplier  log_change  \
# tick
# 0         0.98592             0.0                     0.0         0.0
# 1         0.98592             0.0                     0.0         0.0
# 2         0.98592             0.0                     0.0         0.0
# 3         0.98592             0.0                     0.0         0.0
# 4         0.98592             0.0                     0.0         0.0
#
#         epoch    beat  song_time
# tick
# 0     16801.0  6715.8        0.0
# 1     16802.0  6716.2        0.2
# 2     16803.0  6716.6        0.4
# 3     16804.0  6717.0        0.6
# 4     16805.0  6717.4        0.8

# %%
# Set up a functions to scale magnitude to match your desired mode/key and octave range.
def mag_to_pitch_tuned(magnitude, scale="linear", reversed=False, debug=False):
    # Where does this data point sit in the domain of your data? (I.E. the min magnitude is 3, the max in 5.6). In this case the optional 'True' means the scale is reversed, so the highest value will return the lowest percentage.
    if scale == "linear":
        scale_pct = midi.linear_scale_pct(ts[pitch_var].min(), ts[pitch_var].max(), magnitude, reversed)
    elif scale == "log":
        scale_pct = midi.log_scale_pct(ts[pitch_var].min(), ts[pitch_var].max(), magnitude, reversed)
    else:
        raise Exception("Invalid scale type '%s'" % scale)
    # Pick a range of notes. This allows you to play in a key.
    c_major = ['C', 'D', 'E', 'F', 'G', 'A', 'B']
    d_minor = ['D', 'E', 'F', 'G', 'A', 'Bb', 'C']
    #Find the note that matches your data point
    note = midi.scale_to_note(scale_pct, d_minor)
    #Translate that note to a MIDI pitch
    midi_pitch = midi.note_to_midi_pitch(note)

    return pd.Series({"a": midi_pitch, "b": note, "c": scale_pct})

# %%
# Change the ISE values to sensible mode/key and octave range.
# remove all the zeroes before adding it to out
ts[["tuned_pitch", "note", "scale_pct"]]  = ts[pitch_var].apply(mag_to_pitch_tuned, scale="linear", reversed=False)
# Run some stats
print pd.concat([ts[15:20], ts[48:53], ts[60:80]])
print "Range for tuned pitch: (%d, %d)" % (ts.tuned_pitch.min(), ts.tuned_pitch.max()) 
print "\nPitch values for Peak Region (May 2010): "
print ts[[pitch_var, "song_time", "tuned_pitch", "note"]].iloc[335:345]
print "\nValue Counts of Notes: "
print ts.note.value_counts()
# Note - The peak happens around t = 40 seconds
# Out:
#       index_price  percent_change  change_with_multiplier  log_change  \
# tick
# 15        0.98592          0.0000                   0.000    0.000000
# 16        0.98768          0.0018                   0.176    0.087102
# 17        0.98768          0.0000                   0.000    0.000000
# 18        0.98768          0.0000                   0.000    0.000000
# 19        0.98768          0.0000                   0.000    0.000000
# 48        0.98945          0.0000                   0.000    0.000000
# 49        0.98945          0.0000                   0.000    0.000000
# 50        0.91742         -0.0785                  -7.203   -0.499999
# 51        0.91646         -0.0011                  -0.097   -0.048348
# 52        0.91624         -0.0002                  -0.022   -0.010998
# 60        0.91007         -0.0009                  -0.083   -0.041405
# 61        0.90920         -0.0010                  -0.087   -0.043391
# 62        0.90832         -0.0010                  -0.088   -0.043887
# 63        0.90747         -0.0009                  -0.086   -0.042894
# 64        0.90658         -0.0010                  -0.089   -0.044383
# 65        0.90571         -0.0010                  -0.087   -0.043391
# 66        0.90485         -0.0010                  -0.086   -0.042894
# 67        0.90401         -0.0009                  -0.084   -0.041901
# 68        0.90318         -0.0009                  -0.083   -0.041405
# 69        0.90237         -0.0009                  -0.081   -0.040412
# 70        0.90157         -0.0009                  -0.080   -0.039915
# 71        0.90079         -0.0009                  -0.078   -0.038921
# 72        0.90001         -0.0009                  -0.078   -0.038921
# 73        0.89928         -0.0008                  -0.074   -0.036933
# 74        0.89852         -0.0008                  -0.075   -0.037430
# 75        0.89777         -0.0008                  -0.075   -0.037430
# 76        0.89698         -0.0009                  -0.080   -0.039915
# 77        0.89620         -0.0009                  -0.077   -0.038424
# 78        0.89538         -0.0009                  -0.083   -0.041405
# 79        0.89457         -0.0009                  -0.081   -0.040412
#
#         epoch     beat  song_time  tuned_pitch note  scale_pct
# tick
# 15    16816.0  6721.80      3.000           91   G7   0.850937
# 16    16817.0  6722.20      3.200           94  Bb7   0.999175
# 17    16818.0  6722.60      3.400           91   G7   0.850937
# 18    16819.0  6723.00      3.600           91   G7   0.850937
# 19    16820.0  6723.39      3.795           91   G7   0.850937
# 48    16849.0  6734.99      9.595           91   G7   0.850937
# 49    16850.0  6735.39      9.795           91   G7   0.850937
# 50    16851.0  6735.79      9.995           62   D5   0.000000
# 51    16852.0  6736.19     10.195           88   E7   0.768654
# 52    16853.0  6736.59     10.395           89   F7   0.832220
# 60    16861.0  6739.78     11.990           88   E7   0.780471
# 61    16862.0  6740.18     12.190           88   E7   0.777092
# 62    16863.0  6740.58     12.390           88   E7   0.776247
# 63    16864.0  6740.98     12.590           88   E7   0.777937
# 64    16865.0  6741.38     12.790           88   E7   0.775403
# 65    16866.0  6741.78     12.990           88   E7   0.777092
# 66    16867.0  6742.18     13.190           88   E7   0.777937
# 67    16868.0  6742.58     13.390           88   E7   0.779626
# 68    16869.0  6742.98     13.590           88   E7   0.780471
# 69    16870.0  6743.38     13.790           88   E7   0.782162
# 70    16871.0  6743.78     13.990           88   E7   0.783007
# 71    16872.0  6744.18     14.190           88   E7   0.784698
# 72    16873.0  6744.58     14.390           88   E7   0.784698
# 73    16874.0  6744.98     14.590           88   E7   0.788083
# 74    16875.0  6745.38     14.790           88   E7   0.787236
# 75    16876.0  6745.78     14.990           88   E7   0.787236
# 76    16877.0  6746.18     15.190           88   E7   0.783007
# 77    16878.0  6746.58     15.390           88   E7   0.785544
# 78    16879.0  6746.98     15.590           88   E7   0.780471
# 79    16880.0  6747.38     15.790           88   E7   0.782162
# Range for tuned pitch: (62, 94)
#
# Pitch values for Peak Region (May 2010):
# Empty DataFrame
# Columns: [log_change, song_time, tuned_pitch, note]
# Index: []
#
# Value Counts of Notes:
# G7     65
# E7     47
# F7      5
# Bb7     2
# D5      1
# Name: note, dtype: int64

# %%
# Now plot timeseries with the original magnitude and the tuned pitch
# plot time series and save the figure 
from mpl_toolkits.axes_grid1 import AxesGrid
import seaborn as sns


fig = sns.plt.figure(figsize=(12, 8))
sns.plt.subplot(411)
sns.plt.plot(ts["index_price"], "-")
sns.plt.ylabel("Index price")
sns.plt.title("Agent-Based Simulation")

sns.plt.subplot(412)
sns.plt.plot(ts["percent_change"], "-")
sns.plt.ylabel("Percent Change")

sns.plt.subplot(413)
sns.plt.plot(ts[pitch_var], "-")
sns.plt.ylabel("Sigmoid Change")

ax = sns.plt.subplot(414)
# sns.plt.bar(ts["tuned_pitch"].index, [ts["tuned_pitch"].iloc[i] if ts[pitch_var].iloc[i] != 0 else 0 for i in range(len(ts))])
sns.plt.plot(ts["tuned_pitch"], 'r-')
sns.plt.xlabel("Ticks")
sns.plt.ylabel("Pitch")

for  i in range(len(ts)):
    if ts[pitch_var].iloc[i] == 0:
        continue
    if ts["note"].iloc[i] == ts["note"].iloc[i-1]:
        continue
    ax.annotate(ts["note"].iloc[i], (i, ts["tuned_pitch"].iloc[i]), xytext=(5,-5), textcoords='offset points',
                family='sans-serif', fontsize=10)

fig.canvas.draw()

sns.plt.show()

# %%
# Build the node list
note_list = []
for i in range(len(ts)):
    # No notes for zeroes
    if ts[pitch_var].iloc[i] == 0:
         continue

    note_list.append([
        ts['beat'].iloc[i] - start_time,
        ts['tuned_pitch'].iloc[i],
        100,  # velocity
        1  # duration, in beats
    ])

print len(note_list)
# Add a track with those notes
midi.add_track(note_list)

# Save the .mid file to disk. 
midi.save_midi()

# You can convert the .mid file to a .wav file by using the utility timidity
# timidity ise.mid -Ow
# timidity can be installed using apt-get

# **Note** - the peak occurs around 40 seconds where you can hear a different note playing
# Out:
# 55
# (94, 6.3999999999996362, 1, 100)
# (94, 18.389999999999418, 1, 100)
# (62, 19.989999999999782, 1, 100)
# (88, 20.389999999999418, 1, 100)
# (89, 20.789999999999964, 1, 100)
# (89, 21.1899999999996, 1, 100)
# (88, 21.590000000000146, 1, 100)
# (88, 21.989999999999782, 1, 100)
# (88, 22.380000000000109, 1, 100)
# (88, 22.779999999999745, 1, 100)
# (88, 23.179999999999382, 1, 100)
# (88, 23.579999999999927, 1, 100)
# (88, 23.979999999999563, 1, 100)
# (88, 24.380000000000109, 1, 100)
# (88, 24.779999999999745, 1, 100)
# (88, 25.179999999999382, 1, 100)
# (88, 25.579999999999927, 1, 100)
# (88, 25.979999999999563, 1, 100)
# (88, 26.380000000000109, 1, 100)
# (88, 26.779999999999745, 1, 100)
# (88, 27.179999999999382, 1, 100)
# (88, 27.579999999999927, 1, 100)
# (88, 27.979999999999563, 1, 100)
# (88, 28.380000000000109, 1, 100)
# (88, 28.779999999999745, 1, 100)
# (88, 29.179999999999382, 1, 100)
# (88, 29.579999999999927, 1, 100)
# (88, 29.979999999999563, 1, 100)
# (88, 30.380000000000109, 1, 100)
# (88, 30.779999999999745, 1, 100)
# (88, 31.179999999999382, 1, 100)
# (88, 31.579999999999927, 1, 100)
# (88, 31.979999999999563, 1, 100)
# (88, 32.380000000000109, 1, 100)
# (88, 32.779999999999745, 1, 100)
# (88, 33.179999999999382, 1, 100)
# (88, 33.579999999999927, 1, 100)
# (88, 33.979999999999563, 1, 100)
# (88, 34.380000000000109, 1, 100)
# (88, 34.779999999999745, 1, 100)
# (88, 35.179999999999382, 1, 100)
# (88, 35.579999999999927, 1, 100)
# (88, 35.979999999999563, 1, 100)
# (88, 36.380000000000109, 1, 100)
# (88, 36.769999999999527, 1, 100)
# (88, 37.170000000000073, 1, 100)
# (89, 37.569999999999709, 1, 100)
# (88, 37.970000000000255, 1, 100)
# (88, 38.369999999999891, 1, 100)
# (89, 38.769999999999527, 1, 100)
# (88, 39.170000000000073, 1, 100)
# (88, 39.569999999999709, 1, 100)
# (88, 39.970000000000255, 1, 100)
# (89, 40.369999999999891, 1, 100)
# (88, 41.170000000000073, 1, 100)
# (94, 6.3999999999996362, 1, 100)
# (94, 18.389999999999418, 1, 100)
# (62, 19.989999999999782, 1, 100)
# (88, 20.389999999999418, 1, 100)
# (89, 20.789999999999964, 1, 100)
# (89, 21.1899999999996, 1, 100)
# (88, 21.590000000000146, 1, 100)
# (88, 21.989999999999782, 1, 100)
# (88, 22.380000000000109, 1, 100)
# (88, 22.779999999999745, 1, 100)
# (88, 23.179999999999382, 1, 100)
# (88, 23.579999999999927, 1, 100)
# (88, 23.979999999999563, 1, 100)
# (88, 24.380000000000109, 1, 100)
# (88, 24.779999999999745, 1, 100)
# (88, 25.179999999999382, 1, 100)
# (88, 25.579999999999927, 1, 100)
# (88, 25.979999999999563, 1, 100)
# (88, 26.380000000000109, 1, 100)
# (88, 26.779999999999745, 1, 100)
# (88, 27.179999999999382, 1, 100)
# (88, 27.579999999999927, 1, 100)
# (88, 27.979999999999563, 1, 100)
# (88, 28.380000000000109, 1, 100)
# (88, 28.779999999999745, 1, 100)
# (88, 29.179999999999382, 1, 100)
# (88, 29.579999999999927, 1, 100)
# (88, 29.979999999999563, 1, 100)
# (88, 30.380000000000109, 1, 100)
# (88, 30.779999999999745, 1, 100)
# (88, 31.179999999999382, 1, 100)
# (88, 31.579999999999927, 1, 100)
# (88, 31.979999999999563, 1, 100)
# (88, 32.380000000000109, 1, 100)
# (88, 32.779999999999745, 1, 100)
# (88, 33.179999999999382, 1, 100)
# (88, 33.579999999999927, 1, 100)
# (88, 33.979999999999563, 1, 100)
# (88, 34.380000000000109, 1, 100)
# (88, 34.779999999999745, 1, 100)
# (88, 35.179999999999382, 1, 100)
# (88, 35.579999999999927, 1, 100)
# (88, 35.979999999999563, 1, 100)
# (88, 36.380000000000109, 1, 100)
# (88, 36.769999999999527, 1, 100)
# (88, 37.170000000000073, 1, 100)
# (89, 37.569999999999709, 1, 100)
# (88, 37.970000000000255, 1, 100)
# (88, 38.369999999999891, 1, 100)
# (89, 38.769999999999527, 1, 100)
# (88, 39.170000000000073, 1, 100)
# (88, 39.569999999999709, 1, 100)
# (88, 39.970000000000255, 1, 100)
# (89, 40.369999999999891, 1, 100)
# (88, 41.170000000000073, 1, 100)
# (94, 6.3999999999996362, 1, 100)
# (94, 18.389999999999418, 1, 100)
# (62, 19.989999999999782, 1, 100)
# (88, 20.389999999999418, 1, 100)
# (89, 20.789999999999964, 1, 100)
# (89, 21.1899999999996, 1, 100)
# (88, 21.590000000000146, 1, 100)
# (88, 21.989999999999782, 1, 100)
# (88, 22.380000000000109, 1, 100)
# (88, 22.779999999999745, 1, 100)
# (88, 23.179999999999382, 1, 100)
# (88, 23.579999999999927, 1, 100)
# (88, 23.979999999999563, 1, 100)
# (88, 24.380000000000109, 1, 100)
# (88, 24.779999999999745, 1, 100)
# (88, 25.179999999999382, 1, 100)
# (88, 25.579999999999927, 1, 100)
# (88, 25.979999999999563, 1, 100)
# (88, 26.380000000000109, 1, 100)
# (88, 26.779999999999745, 1, 100)
# (88, 27.179999999999382, 1, 100)
# (88, 27.579999999999927, 1, 100)
# (88, 27.979999999999563, 1, 100)
# (88, 28.380000000000109, 1, 100)
# (88, 28.779999999999745, 1, 100)
# (88, 29.179999999999382, 1, 100)
# (88, 29.579999999999927, 1, 100)
# (88, 29.979999999999563, 1, 100)
# (88, 30.380000000000109, 1, 100)
# (88, 30.779999999999745, 1, 100)
# (88, 31.179999999999382, 1, 100)
# (88, 31.579999999999927, 1, 100)
# (88, 31.979999999999563, 1, 100)
# (88, 32.380000000000109, 1, 100)
# (88, 32.779999999999745, 1, 100)
# (88, 33.179999999999382, 1, 100)
# (88, 33.579999999999927, 1, 100)
# (88, 33.979999999999563, 1, 100)
# (88, 34.380000000000109, 1, 100)
# (88, 34.779999999999745, 1, 100)
# (88, 35.179999999999382, 1, 100)
# (88, 35.579999999999927, 1, 100)
# (88, 35.979999999999563, 1, 100)
# (88, 36.380000000000109, 1, 100)
# (88, 36.769999999999527, 1, 100)
# (88, 37.170000000000073, 1, 100)
# (89, 37.569999999999709, 1, 100)
# (88, 37.970000000000255, 1, 100)
# (88, 38.369999999999891, 1, 100)
# (89, 38.769999999999527, 1, 100)
# (88, 39.170000000000073, 1, 100)
# (88, 39.569999999999709, 1, 100)
# (88, 39.970000000000255, 1, 100)
# (89, 40.369999999999891, 1, 100)
# (88, 41.170000000000073, 1, 100)
